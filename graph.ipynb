# %%
class Graph: 
    def __init__(self, edges):
        self.edges = edges 
        self.graph_dict  = {}
        for start , end in self.edges: 
            if start in self.graph_dict: 
                self.graph_dict[start].append(end)
            else: 
                self.graph_dict[start] = [end]
        
        print("Graph dict:" , self.graph_dict)
    
    
    def get_paths(self , start , end , path = []):
        path = path + [start]
        
        
        if start == end: 
            return [path]
        
        
        if start not in self.graph_dict: 
            return []
        
        
        
        paths  = []
        
        
        for node in self.graph_dict[start]:
            if node not in path: 
                new_paths = self.get_paths(node , end , path)
                for p in new_paths: 
                    paths.append(p)
        return paths
    
def get_shortes_path(self , start , end , path = []):
    
    path = path + [start]
    
    if start == path: 
        return path 
    
    if start not in self.graph_dict: 
        return None 
    
    
    shortes_path = None 
    for node in self.graph_dict[start]:
        if node not in path: 
            sp = self.get_shortest_path(node , end , path)
            if sp:
                if shortes_path is None or len(sp) < len(shortes_path):
                    shortes_path = sp
    return  shortes_path
                



if __name__ == "__main__":
    routes = [
        ("Mumbai" , "Paris"),
        ("Mumbai" , "Dubai"),
        ("Paris" , "Dubai"),
        ("Dubai" , "New York"),
        ("New York" , "Toronoto")
    ]

route_graph = Graph(routes)

start = "Toronoto"
end = "New York"

print(f"Shortes Path between {start} and {end}:", route_graph.get_shortest_path(start, end))
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai'], 'Dubai': ['New York'], 'New York': ['Toronoto']}

# %%
print(route_graph)

# %%
class Graph: 
    def __init__(self):
        self.graph = {} # Dictionary to sgtore the graph 
    
    def add_vertex(self , vertex): 
        if vertex not in self.graph: 
            self.graph[vertex] = []  # Intialize an empty list for new vertices
    
    
    def add_edge(self , vertex1 , vertex2):
        # Add an edge between vertex1 and vertex2 (undirected graph)
        if vertex1 in self.graph and vertex2 in self.graph: 
            self.graph[vertex1].append(vertex2)
            self.graph[vertex2].append(vertex1)
        
        else:
            print("one or both vertices not found in the graph.")
    
    def display_graph(self):
        for vertex , edges in self.graph.items():
            print(f"{vertex}: {edges}")

# %%
# Example usage 
g = Graph()
g.add_vertex("A")
g.add_vertex("B")
g.add_vertex("C")
g.add_vertex("D")


g.add_edge("A" , "B")
g.add_edge("A" , "C")
g.add_edge("B" , "D")
g.add_edge("C" , "D")

# %%
a = [1]
b = [2]

print(a + b)
# Out:
# [1, 2]

# %%
# implementation of graphs 

class Graph: 
    def __init__(self , edges):
        self.edges = edges
        self.graph_dict = {}
        for start , end in self.edges:
            if start in self.graph_dict: 
                self.graph_dict[start].append(end)
            else: 
                self.graph_dict[start] = [end]
        print("Graph Dict:" , self.graph_dict)
    
    
    def get_paths(self , start , end , path = []):
        path = path + [start]
        
        
        if start == end:
            return [path]
        
        if start not in self.graph_dict: 
            return []
        
        paths  = []
        for node in self.graph_dict[start]:
            if node not in path: 
                new_paths = self.get_paths(node , end , path)
                for p in new_paths: 
                    paths.append(p)
        return paths
    
    
    def get_shortes_path(self , start , end , path = []):
        path = path + [start]
        
        
        if start == end:
            return path
        
        if start not in self.graph_dict: 
            return None 
        
        shortest_path = None 
        for node in self.graph_dict[start]:
            if node not in path: 
                sp = self.get_shortes_path(node , end , path)
                if sp: 
                    if get_shortes_path is None or len(sp)  < len(shortest_path):
                        shortes_path = sp 
        
        
        return shortest_path



if __name__ == "__main__":
    routes  = [ 
               ("Mumbai" , "Paris"),
               ("Mumbai" , "Dubai"),
               ("Paris" , "New York"),
               ("Dubai" , "New York"),
               ("New York" , "Tornoto")
               ]

    route_graph = Graph(routes)
    
    
    start = "Mumbai"
    end = "New York"
    
    print(f"Paths between {start} and {end}:" , route_graph.get_paths(start , end))
# Out:
# Graph Dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['New York'], 'Dubai': ['New York'], 'New York': ['Tornoto']}
# Paths between Mumbai and New York: [['Mumbai', 'Paris', 'New York'], ['Mumbai', 'Dubai', 'New York']]

# %%
class Graph: 
    def __init__(self):
        self.graph = {}  # Dictionary to store graph
    
    
    def add_vertex(self , vertex):
        if vertex not in self.graph: 
            self.graph[vertex] = []   # Initialize an empty list for new vertices
    
    def add_edge(self , vertex1 , vertex2):  # Add the edges 
        
        # Add an undirected edge between vertex1 and vertex2 
        if vertex1 in self.graph and vertex2 in self.graph: 
            self.graph[vertex1].append(vertex2)
            self.graph[vertex2].append(vertex1)
            
            
            
        else: 
            print("one or both vertices not found in the graph")
    
    def display_graph(self):
        for vertex , edges in self.graph.items():
            print(f"{vertex}: {edges}")




# Example usage 
g = Graph()
g.add_vertex("Alice")
g.add_vertex("Bob")
g.add_vertex("Carol")
g.add_vertex("Dave")


g.add_edge("Alice" , "Bob")
g.add_edge("Alice" , "Carol")
g.add_edge("Bob" , "Dave")
g.add_edge("Carol" , "Dave")
g.add_edge("Carol" , "Dav")



g.display_graph()
# Out:
# one or both vertices not found in the graph
# Alice: ['Bob', 'Carol']
# Bob: ['Alice', 'Dave']
# Carol: ['Alice', 'Dave']
# Dave: ['Bob', 'Carol']

# %%
class Graph: 
    
    def __init__(self):
        self.graph = {}  # Dictionary to store the graph 
    
    def add_vertex(self , vertex):
        if vertex not in self.graph: 
            self.graph[vertex] = []  # Initialize an empty list for new vertices 
    
    def add_edge(self , vertex1 , vertex2):
        # Add a directed edge from vertex1 to vertex2 
        if vertex1 in self.graph: 
            self.graph[vertex1].append(vertex2)
        
        else: 
            print(f"Vertex  {vertex1} not found in the graph.")
            
    
    def display_graph(self):
        for vertex , edges in self.graph.items():
            print(f"{vertex}:  {edges}")

# Example usage 

g = Graph()
g.add_vertex('CS101')
g.add_vertex('CS102')
g.add_vertex('CS103')
g.add_vertex('CS201')


g.add_edge("CS101" , "CS102")
g.add_edge("CS102" , "CS103")
g.add_edge("CS101" , "CS201")



g.display_graph()
# Out:
# CS101:  ['CS102', 'CS201']
# CS102:  ['CS103']
# CS103:  []
# CS201:  []

# %%
# Python Implementation 


class Graph: 
    def __init__(self):
        self.graph = {}
        
    def add_vertex(self , vertex):
        if vertex not in self.graph: 
            self.graph[vertex] = []
            
        
        
    def add_edge(self , vertex1 , vertex2 , weight):
        # Add a weighted edges from vertex1 to vertex2 
        if vertex1 in self.graph and vertex2 in self.graph: 
            self.graph[vertex1].append((vertex2 , weight))
            self.graph[vertex2].append((vertex1 , weight))
        
        else: 
            print(f"One or both vertices bot found in the graph")
    
    
    def display_graph(self):
        for vertex , edges in self.graph.items():
            print(f"{vertex}: {edges}")


# Example usage 
g = Graph()
g.add_vertex('A')
g.add_vertex('B')
g.add_vertex('C')
g.add_vertex('D')
g.add_vertex('E')


g.add_edge('A' , 'B' , 5)
g.add_edge('A' , 'B' , 10)
g.add_edge('A' , 'B' , 3)
g.add_edge('A' , 'B' , 7)
g.add_edge('A' , 'B' , 4)



g.display_graph()
# Out:
# A: [('B', 5), ('B', 10), ('B', 3), ('B', 7), ('B', 4)]
# B: [('A', 5), ('A', 10), ('A', 3), ('A', 7), ('A', 4)]
# C: []
# D: []
# E: []
